# %%
import pandas as pd

# %%
df=pd.read_csv('Order_v3.csv',  encoding='latin1')

# %%
df.head(3).transpose()
# Out:
#                                                                              0  \
# orderIdentifier                                                      100044349
# orderType                                                             OUTBOUND
# vendor.organizationIdentifier                                        LightTree
# buyer.organizationIdentifier                                              AHTD
# shipFromInstructionLocation.locationIdentifier                            LT-1
# shipToLocation.locationIdentifier                           AHTD - Bentonville
# orderStatus                                                                NaN
# createdDate                                                2021-06-08T00:00:00
# requestedShipDate                                          2021-07-20T00:00:00
# requestedDeliveryDate                                      2021-07-30T00:00:00
# plannedShipDate                                            2021-07-23T00:00:00
# ...

# %%
len(df.columns.tolist())
# Out:
# 20

# %%
#Looks like few columns has all null values init, so removing it
df.dropna(axis=1,how='all')
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 0          100044349  OUTBOUND                     LightTree
# 1          100044350  OUTBOUND                     LightTree
# 2          100044353  OUTBOUND                     LightTree
# 3          100055001  OUTBOUND                     LightTree
# 4          100055003  OUTBOUND                     LightTree
# ..               ...       ...                           ...
# 209        100044330  OUTBOUND                     LightTree
# 210        100044331  OUTBOUND                     LightTree
# 211        100044332  OUTBOUND                     LightTree
# 212        100055004  OUTBOUND                     LightTree
# 213        100055011  OUTBOUND                     LightTree
#
#     buyer.organizationIdentifier  \
# 0                           AHTD
# 1                           AHTD
# 2                           AHTD
# 3                           AHTD
# 4                           AHTD
# ...

# %%
# 3 columns has been entirely dropped
# orderStatus totalShippedQuantity exlucde

# %%
# Out of these 17 Columns, I selected some useful columns
updated_df = df[['orderIdentifier','vendor.organizationIdentifier','buyer.organizationIdentifier','quantity','totalValue']]

# %%
# updated_df.isna().sum() -> with identified we dont have any null values

# %%
updated_df = updated_df.sort_values('quantity',ascending=False)

# %%
updated_df.to_csv('only_5_row_order_data.csv',index=False)
